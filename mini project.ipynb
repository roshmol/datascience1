# %%
                                         #MINIPROJECT
#About
#The HDB resale price data  containing  resale transactions from 1990 to 1999

# %%
import pandas as pd
import seaborn as sb

import numpy  as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("resale-flat-prices-based-on-approval-date-1990-1999.csv")

# %%
df
# Out:
#           month        town  flat_type block       street_name storey_range  \
# 0       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4       1990-01  ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
# ...         ...         ...        ...   ...               ...          ...
# 287195  1999-12      YISHUN  EXECUTIVE   611      YISHUN ST 61     10 TO 12
# 287196  1999-12      YISHUN  EXECUTIVE   324       YISHUN CTRL     01 TO 03
# 287197  1999-12      YISHUN  EXECUTIVE   392      YISHUN AVE 6     07 TO 09
# 287198  1999-12      YISHUN  EXECUTIVE   356    YISHUN RING RD     04 TO 06
# 287199  1999-12      YISHUN  EXECUTIVE   358    YISHUN RING RD     01 TO 03
#
# ...

# %%
df.head()
# Out:
#      month        town flat_type block       street_name storey_range  \
# 0  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4  1990-01  ANG MO KIO    3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price
# 0            31.0        IMPROVED                 1977          9000
# 1            31.0        IMPROVED                 1977          6000
# 2            31.0        IMPROVED                 1977          8000
# 3            31.0        IMPROVED                 1977          6000
# 4            73.0  NEW GENERATION                 1976         47200

# %%
df.tail()
# Out:
#           month    town  flat_type block     street_name storey_range  \
# 287195  1999-12  YISHUN  EXECUTIVE   611    YISHUN ST 61     10 TO 12
# 287196  1999-12  YISHUN  EXECUTIVE   324     YISHUN CTRL     01 TO 03
# 287197  1999-12  YISHUN  EXECUTIVE   392    YISHUN AVE 6     07 TO 09
# 287198  1999-12  YISHUN  EXECUTIVE   356  YISHUN RING RD     04 TO 06
# 287199  1999-12  YISHUN  EXECUTIVE   358  YISHUN RING RD     01 TO 03
#
#         floor_area_sqm  flat_model  lease_commence_date  resale_price
# 287195           142.0   APARTMENT                 1987        456000
# 287196           142.0   APARTMENT                 1988        408000
# 287197           146.0  MAISONETTE                 1988        469000
# 287198           146.0  MAISONETTE                 1988        440000
# 287199           145.0  MAISONETTE                 1988        484000

# %%
df.drop(['block'],axis=1,inplace=True)
df
# Out:
#           month        town  flat_type       street_name storey_range  \
# 0       1990-01  ANG MO KIO     1 ROOM  ANG MO KIO AVE 1     10 TO 12
# 1       1990-01  ANG MO KIO     1 ROOM  ANG MO KIO AVE 1     04 TO 06
# 2       1990-01  ANG MO KIO     1 ROOM  ANG MO KIO AVE 1     10 TO 12
# 3       1990-01  ANG MO KIO     1 ROOM  ANG MO KIO AVE 1     07 TO 09
# 4       1990-01  ANG MO KIO     3 ROOM  ANG MO KIO AVE 1     04 TO 06
# ...         ...         ...        ...               ...          ...
# 287195  1999-12      YISHUN  EXECUTIVE      YISHUN ST 61     10 TO 12
# 287196  1999-12      YISHUN  EXECUTIVE       YISHUN CTRL     01 TO 03
# 287197  1999-12      YISHUN  EXECUTIVE      YISHUN AVE 6     07 TO 09
# 287198  1999-12      YISHUN  EXECUTIVE    YISHUN RING RD     04 TO 06
# 287199  1999-12      YISHUN  EXECUTIVE    YISHUN RING RD     01 TO 03
#
#         floor_area_sqm      flat_model  lease_commence_date  resale_price
# ...

# %%
df.dtypes
# Out:
# month                   object
# town                    object
# flat_type               object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# resale_price             int64
# dtype: object

# %%
df.describe()
# Out:
#        floor_area_sqm  lease_commence_date   resale_price
# count   287200.000000        287200.000000  287200.000000
# mean        93.351439          1983.206741  219541.850313
# std         27.361839             6.085734  128144.384286
# min         28.000000          1967.000000    5000.000000
# 25%         68.000000          1979.000000  127000.000000
# 50%         91.000000          1984.000000  195000.000000
# 75%        113.000000          1987.000000  298000.000000
# max        307.000000          1997.000000  900000.000000

# %%
df.drop(['lease_commence_date'],axis=1,inplace=True)
df
# Out:
#           month        town  flat_type       street_name storey_range  \
# 0       1990-01  ANG MO KIO     1 ROOM  ANG MO KIO AVE 1     10 TO 12
# 1       1990-01  ANG MO KIO     1 ROOM  ANG MO KIO AVE 1     04 TO 06
# 2       1990-01  ANG MO KIO     1 ROOM  ANG MO KIO AVE 1     10 TO 12
# 3       1990-01  ANG MO KIO     1 ROOM  ANG MO KIO AVE 1     07 TO 09
# 4       1990-01  ANG MO KIO     3 ROOM  ANG MO KIO AVE 1     04 TO 06
# ...         ...         ...        ...               ...          ...
# 287195  1999-12      YISHUN  EXECUTIVE      YISHUN ST 61     10 TO 12
# 287196  1999-12      YISHUN  EXECUTIVE       YISHUN CTRL     01 TO 03
# 287197  1999-12      YISHUN  EXECUTIVE      YISHUN AVE 6     07 TO 09
# 287198  1999-12      YISHUN  EXECUTIVE    YISHUN RING RD     04 TO 06
# 287199  1999-12      YISHUN  EXECUTIVE    YISHUN RING RD     01 TO 03
#
#         floor_area_sqm      flat_model  resale_price
# 0                 31.0        IMPROVED          9000
# ...

# %%
# label encoding
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
df["town"]=lb.fit_transform(df["town"])
df
# Out:
#           month  town  flat_type       street_name storey_range  \
# 0       1990-01     0     1 ROOM  ANG MO KIO AVE 1     10 TO 12
# 1       1990-01     0     1 ROOM  ANG MO KIO AVE 1     04 TO 06
# 2       1990-01     0     1 ROOM  ANG MO KIO AVE 1     10 TO 12
# 3       1990-01     0     1 ROOM  ANG MO KIO AVE 1     07 TO 09
# 4       1990-01     0     3 ROOM  ANG MO KIO AVE 1     04 TO 06
# ...         ...   ...        ...               ...          ...
# 287195  1999-12    25  EXECUTIVE      YISHUN ST 61     10 TO 12
# 287196  1999-12    25  EXECUTIVE       YISHUN CTRL     01 TO 03
# 287197  1999-12    25  EXECUTIVE      YISHUN AVE 6     07 TO 09
# 287198  1999-12    25  EXECUTIVE    YISHUN RING RD     04 TO 06
# 287199  1999-12    25  EXECUTIVE    YISHUN RING RD     01 TO 03
#
#         floor_area_sqm      flat_model  resale_price
# 0                 31.0        IMPROVED          9000
# 1                 31.0        IMPROVED          6000
# ...

# %%
df["street_name"]=lb.fit_transform(df["street_name"])
df
# Out:
#           month  town  flat_type  street_name storey_range  floor_area_sqm  \
# 0       1990-01     0     1 ROOM            4     10 TO 12            31.0
# 1       1990-01     0     1 ROOM            4     04 TO 06            31.0
# 2       1990-01     0     1 ROOM            4     10 TO 12            31.0
# 3       1990-01     0     1 ROOM            4     07 TO 09            31.0
# 4       1990-01     0     3 ROOM            4     04 TO 06            73.0
# ...         ...   ...        ...          ...          ...             ...
# 287195  1999-12    25  EXECUTIVE          408     10 TO 12           142.0
# 287196  1999-12    25  EXECUTIVE          402     01 TO 03           142.0
# 287197  1999-12    25  EXECUTIVE          399     07 TO 09           146.0
# 287198  1999-12    25  EXECUTIVE          404     04 TO 06           146.0
# 287199  1999-12    25  EXECUTIVE          404     01 TO 03           145.0
#
#             flat_model  resale_price
# ...

# %%
df["flat_type"]=lb.fit_transform(df["flat_type"])
df
# Out:
#           month  town  flat_type  street_name storey_range  floor_area_sqm  \
# 0       1990-01     0          0            4     10 TO 12            31.0
# 1       1990-01     0          0            4     04 TO 06            31.0
# 2       1990-01     0          0            4     10 TO 12            31.0
# 3       1990-01     0          0            4     07 TO 09            31.0
# 4       1990-01     0          2            4     04 TO 06            73.0
# ...         ...   ...        ...          ...          ...             ...
# 287195  1999-12    25          5          408     10 TO 12           142.0
# 287196  1999-12    25          5          402     01 TO 03           142.0
# 287197  1999-12    25          5          399     07 TO 09           146.0
# 287198  1999-12    25          5          404     04 TO 06           146.0
# 287199  1999-12    25          5          404     01 TO 03           145.0
#
#             flat_model  resale_price
# ...

# %%
df["storey_range"]=lb.fit_transform(df["storey_range"])
df
# Out:
#           month  town  flat_type  street_name  storey_range  floor_area_sqm  \
# 0       1990-01     0          0            4             3            31.0
# 1       1990-01     0          0            4             1            31.0
# 2       1990-01     0          0            4             3            31.0
# 3       1990-01     0          0            4             2            31.0
# 4       1990-01     0          2            4             1            73.0
# ...         ...   ...        ...          ...           ...             ...
# 287195  1999-12    25          5          408             3           142.0
# 287196  1999-12    25          5          402             0           142.0
# 287197  1999-12    25          5          399             2           146.0
# 287198  1999-12    25          5          404             1           146.0
# 287199  1999-12    25          5          404             0           145.0
#
#             flat_model  resale_price
# ...

# %%
df["flat_model"]=lb.fit_transform(df["flat_model"])
df
# Out:
#           month  town  flat_type  street_name  storey_range  floor_area_sqm  \
# 0       1990-01     0          0            4             3            31.0
# 1       1990-01     0          0            4             1            31.0
# 2       1990-01     0          0            4             3            31.0
# 3       1990-01     0          0            4             2            31.0
# 4       1990-01     0          2            4             1            73.0
# ...         ...   ...        ...          ...           ...             ...
# 287195  1999-12    25          5          408             3           142.0
# 287196  1999-12    25          5          402             0           142.0
# 287197  1999-12    25          5          399             2           146.0
# 287198  1999-12    25          5          404             1           146.0
# 287199  1999-12    25          5          404             0           145.0
#
#         flat_model  resale_price
# ...

# %%
df.columns
# Out:
# Index(['month', 'town', 'flat_type', 'street_name', 'storey_range',
#        'floor_area_sqm', 'flat_model', 'resale_price'],
#       dtype='object')

# %%
df.shape
# Out:
# (287200, 8)

# %%
df.isnull()
# Out:
#         month   town  flat_type  street_name  storey_range  floor_area_sqm  \
# 0       False  False      False        False         False           False
# 1       False  False      False        False         False           False
# 2       False  False      False        False         False           False
# 3       False  False      False        False         False           False
# 4       False  False      False        False         False           False
# ...       ...    ...        ...          ...           ...             ...
# 287195  False  False      False        False         False           False
# 287196  False  False      False        False         False           False
# 287197  False  False      False        False         False           False
# 287198  False  False      False        False         False           False
# 287199  False  False      False        False         False           False
#
#         flat_model  resale_price
# 0            False         False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 287200 entries, 0 to 287199
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   month           287200 non-null  object
#  1   town            287200 non-null  int32
#  2   flat_type       287200 non-null  int32
#  3   street_name     287200 non-null  int32
#  4   storey_range    287200 non-null  int32
#  5   floor_area_sqm  287200 non-null  float64
#  6   flat_model      287200 non-null  int32
#  7   resale_price    287200 non-null  int64
# dtypes: float64(1), int32(5), int64(1), object(1)
# memory usage: 12.1+ MB

# %%
df['flat_model'].unique()
# Out:
# array([ 2,  8,  5, 11, 10,  6,  1,  4, 12,  0,  3,  7,  9])

# %%
df['storey_range'].unique()
# Out:
# array([3, 1, 2, 0, 4, 6, 5, 8, 7])

# %%
df['town'].unique()
# Out:
# array([ 0,  1,  2,  3,  4,  6,  7,  8,  9, 10, 11, 12, 13, 14, 16, 18, 20,
#        21, 22, 23, 24, 25, 15, 19,  5, 17])

# %%
#Distribution of floor area sqm
plt.hist(df['floor_area_sqm'],bins=50,edgecolor='red')
plt.title('Distribution of floor area')
plt.show()
display(df[df['floor_area_sqm'] > 200]['flat_model'].value_counts())
# Out:
# 12    25
# 4      9
# 1      1
# Name: flat_model, dtype: int64

# %%
#The floor area outliers mostly belong to special HDBs that are larger than the standard ones. So they might not be outliers from a multivariate perspective.

# %%
df["resale_price"].describe()
# Out:
# count    287200.000000
# mean     219541.850313
# std      128144.384286
# min        5000.000000
# 25%      127000.000000
# 50%      195000.000000
# 75%      298000.000000
# max      900000.000000
# Name: resale_price, dtype: float64

# %%
# a huge difference in resale price based on different storey_range
df.groupby("storey_range").mean()["resale_price"].sort_values(ascending = False).plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='storey_range'>

# %%
# a huge difference in resale price based on different floor_area_sqm
df.groupby("flat_model").mean()["resale_price"].sort_values(ascending = False).plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='flat_model'>

# %%
# a huge difference in resale price based on different type of flat

df.groupby("flat_type").mean()["resale_price"].sort_values(ascending = False).plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='flat_type'>

# %%
df.corr()
# Out:
#                     town  flat_type  street_name  storey_range  \
# town            1.000000   0.120944     0.797040     -0.063975
# flat_type       0.120944   1.000000     0.127834      0.043519
# street_name     0.797040   0.127834     1.000000     -0.064699
# storey_range   -0.063975   0.043519    -0.064699      1.000000
# floor_area_sqm  0.123704   0.958644     0.132978      0.025705
# flat_model     -0.142448  -0.350726    -0.122749     -0.073577
# resale_price    0.083831   0.786375     0.099889      0.062944
#
#                 floor_area_sqm  flat_model  resale_price
# town                  0.123704   -0.142448      0.083831
# flat_type             0.958644   -0.350726      0.786375
# street_name           0.132978   -0.122749      0.099889
# storey_range          0.025705   -0.073577      0.062944
# floor_area_sqm        1.000000   -0.385055      0.797008
# flat_model           -0.385055    1.000000     -0.332178
# resale_price          0.797008   -0.332178      1.000000

# %%
# Correlation heatmap
dp=sb.heatmap(df.corr(),cmap="Accent",annot=True)

# %%
x=df.iloc[:,[7]].values

# %%
x
# Out:
# array([[  9000],
#        [  6000],
#        [  8000],
#        ...,
#        [469000],
#        [440000],
#        [484000]], dtype=int64)

# %%
y=df.iloc[:,[-1]].values
y
# Out:
# array([[  9000],
#        [  6000],
#        [  8000],
#        ...,
#        [469000],
#        [440000],
#        [484000]], dtype=int64)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=0)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
ypred=model.predict(x_test)

# %%
ypred
# Out:
# array([[ 24000.        ],
#        [147000.        ],
#        [ 47000.        ],
#        ...,
#        [314000.        ],
#        [376000.        ],
#        [624999.99999999]])

# %%
model.score(x_test,y_test)
# Out:
# 1.0

# %%
#CONCLUSION
#In this project, linear regression and random forest were used to looked at the drivers of HDB resale prices. Linear regression is powerful because it allows one to interpret the results of the model by looking at its coefficients for every feature.
